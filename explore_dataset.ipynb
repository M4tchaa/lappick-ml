# %%
import pandas as pd

# %%
df = pd.read_csv('cleaned_dataset.csv')

# %%
df.head()
# Out:
#   Status   Brand       Model            CPU  RAM  Storage Storage type  \
# 0    New    Asus  ExpertBook  Intel Core i5    8      512          SSD
# 1    New  Alurin          Go  Intel Celeron    8      256          SSD
# 2    New    Asus  ExpertBook  Intel Core i3    8      256          SSD
# 3    New     MSI      Katana  Intel Core i7   16     1000          SSD
# 4    New      HP         15S  Intel Core i5   16      512          SSD
#
#           GPU  Screen  Touch  Final Price
# 0  Integrated    15.6      0   16648500.0
# 1  Integrated    15.6      0    4933500.0
# 2  Integrated    15.6      0   13018500.0
# 3    RTX 3050    15.6      0   19783500.0
# 4  Integrated    15.6      0   11038665.0

# %%
df1 = pd.read_csv('datasets/laptop_data.csv', index_col=0)
df1
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1303 rows x 11 columns]

# %%
df2 = pd.read_csv('datasets/LaptopPricePrediction.csv', index_col=0)
df2
# Out:
#                                                   Name  \
# 0    Lenovo Ideapad S145 Core i5 10th Gen - (8 GB/1...
# 1    Lenovo IdeaPad Core i3 11th Gen - (8 GB/256 GB...
# 2    HP Pentium Quad Core - (8 GB/256 GB SSD/Window...
# 3    HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...
# 4    HP 15s Athlon Dual Core - (4 GB/1 TB HDD/Windo...
# ..                                                 ...
# 545  ASUS ASUS TUF Dash Series Core i7 11th Gen - (...
# 546  ASUS Ryzen 3 Dual Core 3250U - (4 GB/256 GB SS...
# 547  MSI GL65 Leopard Core i7 10th Gen - (16 GB/1 T...
# 548  HP Pavilion Core i7 9th Gen - (12 GB/1 TB HDD/...
# 549  DELL GAMING G5 SERIES Core i5 10th Gen - (8 GB...
#
#                               Processor             RAM  \
# 0    Intel Core i5 Processor (10th Gen)   8 GB DDR4 RAM
# 1    Intel Core i3 Processor (11th Gen)   8 GB DDR4 RAM
# 2     Intel Pentium Quad Core Processor   8 GB DDR4 RAM
# 3    Intel Core i3 Processor (11th Gen)   8 GB DDR4 RAM
# 4        AMD Athlon Dual Core Processor   4 GB DDR4 RAM
# ..                                  ...             ...
# 545     AMD Ryzen 7 Octa Core Processor   8 GB DDR4 RAM
# 546  Intel Core i7 Processor (10th Gen)  16 GB DDR4 RAM
# 547     AMD Ryzen 7 Quad Core Processor   4 GB DDR4 RAM
# 548     AMD Ryzen 7 Octa Core Processor  16 GB DDR4 RAM
# 549  Intel Core i5 Processor (10th Gen)  12 GB DDR4 RAM
#
#                        Operating System              Storage  \
# 0    64 bit Windows 10 Operating System             1 TB HDD
# 1    64 bit Windows 10 Operating System           256 GB SSD
# 2    64 bit Windows 10 Operating System           256 GB SSD
# 3    64 bit Windows 10 Operating System           256 GB SSD
# 4    64 bit Windows 10 Operating System             1 TB HDD
# ..                                  ...                  ...
# 545  64 bit Windows 10 Operating System           256 GB SSD
# 546  64 bit Windows 10 Operating System  1 TB HDD|256 GB SSD
# 547  64 bit Windows 10 Operating System  1 TB HDD|512 GB SSD
# 548         Windows 10 Operating System           512 GB SSD
# 549  64 bit Windows 10 Operating System  1 TB HDD|256 GB SSD
#
#                                                Display  \
# 0                         39.62 cm (15.6 inch) Display
# 1                           35.56 cm (14 Inch) Display
# 2                           35.56 cm (14 inch) Display
# 3                           35.56 cm (14 inch) Display
# 4                         39.62 cm (15.6 inch) Display
# ..                                                 ...
# 545  Matrix Display, Dragon Center, Cooler Boost 5,...
# 546             35.56 cm (14 inch) Touchscreen Display
# 547                       33.78 cm (13.3 inch) Display
# 548                       39.62 cm (15.6 inch) Display
# 549                         35.56 cm (14 inch) Display
#
#                                               Warranty      Price  rating
# 0                               1 Year Onsite Warranty    ₹43,990     3.9
# 1                               1 Year Onsite Warranty    ₹43,990     4.2
# 2                               1 Year Onsite Warranty    ₹31,490     4.6
# 3                               1 Year Onsite Warranty    ₹40,990     4.1
# 4                               1 Year Onsite Warranty    ₹27,490     4.1
# ..                                                 ...        ...     ...
# 545                             1 Year Onsite Warranty  ₹1,36,990     4.9
# 546                             1 Year Onsite Warranty    ₹37,900     3.9
# 547                             1 Year Onsite Warranty  ₹1,09,990     3.5
# 548  1 Year Manufacturer Warranty on the Device and...  ₹1,22,000     4.5
# 549                             1 Year Onsite Warranty    ₹79,990     4.1
#
# [550 rows x 9 columns]

# %%
df3 = pd.read_csv('datasets/laptops.csv', index_col=0)
df3
# Out:
#                                                          Status   Brand  \
# Laptop
# ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core ...          New    Asus
# Alurin Go Start Intel Celeron N4020/8GB/256GB S...          New  Alurin
# ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core ...          New    Asus
# MSI Katana GF66 12UC-082XES Intel Core i7-12700...          New     MSI
# HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB ...          New      HP
# ...                                                         ...     ...
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/1...  Refurbished   Razer
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/1...  Refurbished   Razer
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/3...  Refurbished   Razer
# Razer Book 13 Intel Evo Core i7-1165G7/16GB/1TB...  Refurbished   Razer
# Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/2...  Refurbished   Razer
#
#                                                          Model  \
# Laptop
# ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core ...  ExpertBook
# Alurin Go Start Intel Celeron N4020/8GB/256GB S...          Go
# ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core ...  ExpertBook
# MSI Katana GF66 12UC-082XES Intel Core i7-12700...      Katana
# HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB ...         15S
# ...                                                        ...
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/1...       Blade
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/1...       Blade
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/3...       Blade
# Razer Book 13 Intel Evo Core i7-1165G7/16GB/1TB...        Book
# Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/2...        Book
#
#                                                                   CPU  RAM  \
# Laptop
# ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core ...      Intel Core i5    8
# Alurin Go Start Intel Celeron N4020/8GB/256GB S...      Intel Celeron    8
# ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core ...      Intel Core i3    8
# MSI Katana GF66 12UC-082XES Intel Core i7-12700...      Intel Core i7   16
# HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB ...      Intel Core i5   16
# ...                                                               ...  ...
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/1...      Intel Core i7   16
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/1...      Intel Core i7   16
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/3...      Intel Core i7   32
# Razer Book 13 Intel Evo Core i7-1165G7/16GB/1TB...  Intel Evo Core i7   16
# Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/2...  Intel Evo Core i7   16
#
#                                                     Storage Storage type  \
# Laptop
# ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core ...      512          SSD
# Alurin Go Start Intel Celeron N4020/8GB/256GB S...      256          SSD
# ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core ...      256          SSD
# MSI Katana GF66 12UC-082XES Intel Core i7-12700...     1000          SSD
# HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB ...      512          SSD
# ...                                                     ...          ...
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/1...     1000          SSD
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/1...     1000          SSD
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/3...     1000          SSD
# Razer Book 13 Intel Evo Core i7-1165G7/16GB/1TB...     1000          SSD
# Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/2...      256          SSD
#
#                                                          GPU  Screen Touch  \
# Laptop
# ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core ...       NaN    15.6    No
# Alurin Go Start Intel Celeron N4020/8GB/256GB S...       NaN    15.6    No
# ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core ...       NaN    15.6    No
# MSI Katana GF66 12UC-082XES Intel Core i7-12700...  RTX 3050    15.6    No
# HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB ...       NaN    15.6    No
# ...                                                      ...     ...   ...
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/1...  RTX 3060    17.3    No
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/1...  RTX 3070    17.3    No
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/3...  RTX 3080    17.3    No
# Razer Book 13 Intel Evo Core i7-1165G7/16GB/1TB...       NaN    13.4   Yes
# Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/2...       NaN    13.4   Yes
#
#                                                     Final Price
# Laptop
# ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core ...      1009.00
# Alurin Go Start Intel Celeron N4020/8GB/256GB S...       299.00
# ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core ...       789.00
# MSI Katana GF66 12UC-082XES Intel Core i7-12700...      1199.00
# HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB ...       669.01
# ...                                                         ...
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/1...      2699.99
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/1...      2899.99
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/3...      3399.99
# Razer Book 13 Intel Evo Core i7-1165G7/16GB/1TB...      1899.99
# Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/2...      1699.99
#
# [2160 rows x 11 columns]

# %% [markdown]
# # CPU

# %%
df3['CPU'].value_counts()
# Out:
# Intel Core i7            710
# Intel Core i5            535
# AMD Ryzen 7              156
# Intel Core i3            130
# AMD Ryzen 5              127
# Intel Core i9             94
# Intel Celeron             94
# Intel Evo Core i7         82
# AMD Ryzen 9               44
# AMD Ryzen 3               44
# Intel Evo Core i5         30
# Apple M2                  28
# AMD 3020e                 13
# Apple M2 Pro              13
# Apple M1                  11
# AMD Athlon                10
# Intel Pentium             10
# Apple M1 Pro               7
# Intel Core M3              5
# AMD 3015e                  3
# Microsoft SQ1              3
# Qualcomm Snapdragon 7      3
# AMD Radeon 9               2
# Qualcomm Snapdragon 8      2
# Intel Evo Core i9          1
# Mediatek MT8183            1
# AMD 3015Ce                 1
# AMD Radeon 5               1
# Name: CPU, dtype: int64

# %% [markdown]
# ## Intel

# %%
df3[df3['CPU'].str.contains("Intel", na=False, case=False)]['CPU'].value_counts()
# Out:
# Intel Core i7        710
# Intel Core i5        535
# Intel Core i3        130
# Intel Celeron         94
# Intel Core i9         94
# Intel Evo Core i7     82
# Intel Evo Core i5     30
# Intel Pentium         10
# Intel Core M3          5
# Intel Evo Core i9      1
# Name: CPU, dtype: int64

# %% [markdown]
# ## AMD

# %%
df3[df3['CPU'].str.contains("AMD", na=False, case=False)]['CPU'].value_counts()
# Out:
# AMD Ryzen 7     156
# AMD Ryzen 5     127
# AMD Ryzen 3      44
# AMD Ryzen 9      44
# AMD 3020e        13
# AMD Athlon       10
# AMD 3015e         3
# AMD Radeon 9      2
# AMD Radeon 5      1
# AMD 3015Ce        1
# Name: CPU, dtype: int64

# %% [markdown]
# ## Apple

# %%
df3[df3['CPU'].str.contains("Apple", na=False, case=False)]['CPU'].unique()
# Out:
# array(['Apple M1', 'Apple M2', 'Apple M2 Pro', 'Apple M1 Pro'],
#       dtype=object)

# %% [markdown]
# ## Qualcomm

# %%
df3[df3['CPU'].str.contains("Qualcomm", na=False, case=False)]['CPU'].unique()
# Out:
# array(['Qualcomm Snapdragon 7', 'Qualcomm Snapdragon 8'], dtype=object)

# %% [markdown]
# ## Microsoft

# %%
df3[df3['CPU'].str.contains("Microsoft", na=False, case=False)]['CPU'].unique()
# Out:
# array(['Microsoft SQ1'], dtype=object)

# %% [markdown]
# ## Mediatek

# %%
df3[df3['CPU'].str.contains("Mediatek", na=False, case=False)]['CPU'].unique()
# Out:
# array(['Mediatek MT8183'], dtype=object)
